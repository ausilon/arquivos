# %%
# Import all the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import math
import random
import pandas as pd
from google.colab import files
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
import pandas as pd
import timeit
import os

# %%
# Always reset the pseudo-random numbers generator to a known value so that your results are always the same.
seed = 1234
np.random.seed(seed)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/luiz10ml/tp555-ml/refs/heads/main/misc/polynomialCurve.csv'
df = pd.read_csv(url, header=None)
df = df.dropna()
x = df[0].to_numpy()
y = df[1].to_numpy()

x = x.reshape(len(x),1)
y = y.reshape(len(y),1)

w = np.random.randn(len(x), 1)

y_noisy = y

fig = plt.figure(figsize=(10,10))
plt.plot(x,y,'b.')

# %%
# Set parameters
a1 = -3
a2 = 2
M = 1000

# Generate x1
x1 = np.random.uniform(100, 500, size=(M, 1))

# Generate x2
x2 = np.random.uniform(-1, 1, size=(M, 1))

# Generate noise (w)
w = np.random.randn(M, 1)

# Calculate y
y = a1 * x1 + a2 * x2 + w

# Display the first few values of x1, x2, and y
print("First 5 values of x1:")
print(x1[:5])
print("\nFirst 5 values of x2:")
print(x2[:5])
print("\nFirst 5 values of y:")
print(y[:5])
# Out:
# First 5 values of x1:
# [[171.49531223]
#  [463.49280392]
#  [430.41867982]
#  [487.20624163]
#  [270.82452533]]
#
# First 5 values of x2:
# [[-0.18742669]
#  [ 0.75373246]
#  [ 0.96945947]
#  [-0.26128364]
#  [ 0.76104088]]
#
# First 5 values of y:
# [[ -514.35606389]
#  [-1388.5553558 ]
#  [-1288.23838888]
#  [-1463.44639713]
#  [ -810.87964205]]
